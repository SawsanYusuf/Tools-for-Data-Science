# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sawsan Yusof**
#
# Student

# %% [markdown]
# *I am intrested in data science because I love discovering puzzles behind words and numbers*

# %% [markdown]
# ### The following code performs the addition of two numbers

# %%
6.59+7.3589
# Out:
# 13.9489

# %% [markdown]
# 1. first
# 2. second
# 3. third
#
#
# (https://www.google.com)
#
#
# |sunday | Monday    | Tuseday
# |-------|:---------:|--------:
# |Math   | History   | Arts
# | A     |   C       |  B
